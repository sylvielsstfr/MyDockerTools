# %% [markdown]
# # Dump hdf5 input file
#
# - creation date : March 4th 2021

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (8,6)
import scipy.stats
import sys
import os
import pandas as pd
#sys.path.append('../')
import h5py
#from delight.io import *
#from delight.utils import *
#from delight.photoz_gp import PhotozGP

# %%
plt.rcParams["figure.figsize"] = (12,6)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
files = ["training_100gal.hdf5","validation_10gal.hdf5","test_dc2_training_9816.hdf5","test_dc2_validation_9816.hdf5"]

# %% [markdown]
# # Read hdf5 file

# %%
index=2
filename = files[index] 

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
# Out:
# Keys: <KeysViewHDF5 ['photometry']>

# %%
data
# Out:
# ['id',
#  'mag_err_g_lsst',
#  'mag_err_i_lsst',
#  'mag_err_r_lsst',
#  'mag_err_u_lsst',
#  'mag_err_y_lsst',
#  'mag_err_z_lsst',
#  'mag_g_lsst',
#  'mag_i_lsst',
#  'mag_r_lsst',
#  'mag_u_lsst',
#  'mag_y_lsst',
#  'mag_z_lsst',
#  'redshift']

# %%
f = h5py.File(filename, 'r')

# %%
list(f.keys())
# Out:
# ['photometry']

# %%
photometry = f.get('photometry')

# %%
id=photometry[('id')].value
redshift=photometry[('redshift')].value

mag_err_g_lsst=photometry[('mag_err_g_lsst')].value
mag_err_i_lsst=photometry[('mag_err_i_lsst')].value
mag_err_r_lsst=photometry[('mag_err_r_lsst')].value
mag_err_u_lsst=photometry[('mag_err_u_lsst')].value
mag_err_y_lsst=photometry[('mag_err_y_lsst')].value
mag_err_z_lsst=photometry[('mag_err_z_lsst')].value
mag_g_lsst=photometry[('mag_g_lsst')].value
mag_i_lsst=photometry[('mag_i_lsst')].value
mag_r_lsst=photometry[('mag_r_lsst')].value
mag_u_lsst=photometry[('mag_u_lsst')].value
mag_y_lsst=photometry[('mag_y_lsst')].value
mag_z_lsst=photometry[('mag_z_lsst')].value
# Out:
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   """Entry point for launching an IPython kernel.
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   after removing the cwd from sys.path.
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   """
# /Users/dagoret/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#
# ...

# %%
fig=plt.figure(figsize=(8,4))
ax=fig.add_subplot(111)
ax.hist(redshift,bins=100,facecolor="b");
ax.set_xlabel("$z$")
ax.set_title("redshift")
# Out:
# Text(0.5, 1.0, 'redshift')

# %%
fig=plt.figure(figsize=(18,10))
ax=fig.add_subplot(221)
ax.scatter(redshift,mag_u_lsst,marker="+",color="b")
ax.set_ylim(15,35)
ax.set_xlabel("z")
ax.set_ylabel("mag_u_lsst")
ax=fig.add_subplot(222)
ax.scatter(mag_u_lsst,mag_err_u_lsst,marker="+",color="b")
ax.set_xlim(15,35)
ax.set_xlabel("mag_u_lsst")
ax.set_ylabel("mag_u_lsst error")
plt.suptitle("magnitude u",fontweight='bold',fontsize=15)

ax=fig.add_subplot(223)
ax.hist2d(redshift,mag_u_lsst,(50,50),cmap="jet")
ax.set_ylim(15,35)
ax.set_xlabel("z")
ax.set_ylabel("mag_u_lsst")
ax=fig.add_subplot(224)
ax.hist2d(mag_u_lsst,mag_err_u_lsst,(50,50),cmap="jet")
ax.set_xlim(15,35)
ax.set_xlabel("mag_u_lsst")
ax.set_ylabel("mag_u_lsst error")
plt.suptitle("magnitude u",fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 0.98, 'magnitude u')

# %%
fig=plt.figure(figsize=(18,10))
ax=fig.add_subplot(221)
ax.scatter(redshift,mag_g_lsst,marker="+",color="g")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_g_lsst")
ax=fig.add_subplot(222)
ax.scatter(mag_g_lsst,mag_err_g_lsst,marker="+",color="g")
ax.set_xlim(15,30)
ax.set_xlabel("mag_g_lsst")
ax.set_ylabel("mag_g_lsst error")
plt.suptitle("magnitude g",fontweight='bold',fontsize=15)

ax=fig.add_subplot(223)
ax.hist2d(redshift,mag_g_lsst,(50,50),cmap="jet")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_g_lsst")
ax=fig.add_subplot(224)
ax.hist2d(mag_g_lsst,mag_err_g_lsst,(50,50),cmap="jet")
ax.set_xlim(15,30)
ax.set_xlabel("mag_g_lsst")
ax.set_ylabel("mag_g_lsst error")
plt.suptitle("magnitude g",fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 0.98, 'magnitude g')

# %%
fig=plt.figure(figsize=(18,10))
ax=fig.add_subplot(221)
ax.scatter(redshift,mag_r_lsst,marker="+",color="r")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_r_lsst")
ax=fig.add_subplot(222)
ax.scatter(mag_r_lsst,mag_err_r_lsst,marker="+",color="r")
ax.set_xlim(15,30)
ax.set_xlabel("mag_r_lsst")
ax.set_ylabel("mag_r_lsst error")
plt.suptitle("magnitude r",fontweight='bold',fontsize=15)

ax=fig.add_subplot(223)
ax.hist2d(redshift,mag_r_lsst,(50,50),cmap="jet")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_r_lsst")
ax=fig.add_subplot(224)
ax.hist2d(mag_r_lsst,mag_err_r_lsst,(50,50),cmap="jet")
ax.set_xlim(15,30)
ax.set_xlabel("mag_r_lsst")
ax.set_ylabel("mag_r_lsst error")
plt.suptitle("magnitude r",fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 0.98, 'magnitude r')

# %%
fig=plt.figure(figsize=(18,10))
ax=fig.add_subplot(221)
ax.scatter(redshift,mag_i_lsst,marker="+",color="orange")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_i_lsst")
ax=fig.add_subplot(222)
ax.scatter(mag_i_lsst,mag_err_i_lsst,marker="+",color="orange")
ax.set_xlim(15,30)
ax.set_xlabel("mag_i_lsst")
ax.set_ylabel("mag_i_lsst error")
plt.suptitle("magnitude i",fontweight='bold',fontsize=15)

ax=fig.add_subplot(223)
ax.hist2d(redshift,mag_i_lsst,(50,50),cmap="jet")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_r_lsst")
ax=fig.add_subplot(224)
ax.hist2d(mag_i_lsst,mag_err_i_lsst,(50,50),cmap="jet")
ax.set_xlim(15,30)
ax.set_xlabel("mag_i_lsst")
ax.set_ylabel("mag_i_lsst error")
plt.suptitle("magnitude i",fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 0.98, 'magnitude i')

# %%
fig=plt.figure(figsize=(18,10))
ax=fig.add_subplot(221)
ax.scatter(redshift,mag_z_lsst,marker="+",color="grey")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_z_lsst")
ax=fig.add_subplot(222)
ax.scatter(mag_z_lsst,mag_err_z_lsst,marker="+",color="grey")
ax.set_xlim(15,30)
ax.set_xlabel("mag_z_lsst")
ax.set_ylabel("mag_z_lsst error")
plt.suptitle("magnitude z",fontweight='bold',fontsize=15)

ax=fig.add_subplot(223)
ax.hist2d(redshift,mag_z_lsst,(50,50),cmap="jet")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_z_lsst")
ax=fig.add_subplot(224)
ax.hist2d(mag_z_lsst,mag_err_z_lsst,(50,50),cmap="jet")
ax.set_xlim(15,30)
ax.set_xlabel("mag_z_lsst")
ax.set_ylabel("mag_z_lsst error")
plt.suptitle("magnitude z",fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 0.98, 'magnitude z')

# %%
fig=plt.figure(figsize=(18,10))
ax=fig.add_subplot(221)
ax.scatter(redshift,mag_y_lsst,marker="+",color="k")
ax.set_ylim(15,30)
ax.set_xlabel("y")
ax.set_ylabel("mag_y_lsst")
ax=fig.add_subplot(222)
ax.scatter(mag_y_lsst,mag_err_y_lsst,marker="+",color="k")
ax.set_xlim(15,30)
ax.set_xlabel("mag_y_lsst")
ax.set_ylabel("mag_y_lsst error")
plt.suptitle("magnitude y",fontweight='bold',fontsize=15)

ax=fig.add_subplot(223)
ax.hist2d(redshift,mag_y_lsst,(50,50),cmap="jet")
ax.set_ylim(15,30)
ax.set_xlabel("z")
ax.set_ylabel("mag_y_lsst")
ax=fig.add_subplot(224)
ax.hist2d(mag_y_lsst,mag_err_y_lsst,(50,50),cmap="jet")
ax.set_xlim(15,30)
ax.set_xlabel("mag_y_lsst")
ax.set_ylabel("mag_y_lsst error")
plt.suptitle("magnitude y",fontweight='bold',fontsize=15)
# Out:
# Text(0.5, 0.98, 'magnitude y')

# %% [markdown]
# # Convert to flux

# %%
flux_g_lsst=np.power(10,-0.4*mag_g_lsst)
flux_i_lsst=np.power(10,-0.4*mag_i_lsst)
flux_r_lsst=np.power(10,-0.4*mag_r_lsst)
flux_u_lsst=np.power(10,-0.4*mag_u_lsst)
flux_y_lsst=np.power(10,-0.4*mag_y_lsst)
flux_z_lsst=np.power(10,-0.4*mag_z_lsst)

# %%
plt.hist(flux_r_lsst,bins=100)
plt.yscale('log')

# %%
mag_err_g_lsst
mag_err_i_lsst
mag_err_r_lsst
mag_err_u_lsst
mag_err_y_lsst
mag_err_z_lsst
