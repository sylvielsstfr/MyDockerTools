# %% [markdown]
# # Dump hdf5 input file

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (12,6)
import scipy.stats
import sys
import os
import pandas as pd
#sys.path.append('../')
import h5py
#from delight.io import *
#from delight.utils import *
#from delight.photoz_gp import PhotozGP

# %%
files = ["training_100gal.hdf5","validation_10gal.hdf5","test_dc2_training_9816.hdf5","test_dc2_validation_9816.hdf5"]

# %%
index=2
filename = files[index] 

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
# Out:
# Keys: <KeysViewHDF5 ['photometry']>

# %%
data
# Out:
# ['id',
#  'mag_err_g_lsst',
#  'mag_err_i_lsst',
#  'mag_err_r_lsst',
#  'mag_err_u_lsst',
#  'mag_err_y_lsst',
#  'mag_err_z_lsst',
#  'mag_g_lsst',
#  'mag_i_lsst',
#  'mag_r_lsst',
#  'mag_u_lsst',
#  'mag_y_lsst',
#  'mag_z_lsst',
#  'redshift']

# %%
f = h5py.File(filename, 'r')

# %%
list(f.keys())
# Out:
# ['photometry']

# %%
photometry = f.get('photometry')

# %%
id=photometry[('id')].value
redshift=photometry[('redshift')].value

mag_err_g_lsst=photometry[('mag_err_g_lsst')].value
mag_err_i_lsst=photometry[('mag_err_i_lsst')].value
mag_err_r_lsst=photometry[('mag_err_r_lsst')].value
mag_err_u_lsst=photometry[('mag_err_u_lsst')].value
mag_err_y_lsst=photometry[('mag_err_y_lsst')].value
mag_err_z_lsst=photometry[('mag_err_z_lsst')].value
mag_g_lsst=photometry[('mag_g_lsst')].value
mag_i_lsst=photometry[('mag_i_lsst')].value
mag_r_lsst=photometry[('mag_r_lsst')].value
mag_u_lsst=photometry[('mag_u_lsst')].value
mag_y_lsst=photometry[('mag_y_lsst')].value
mag_z_lsst=photometry[('mag_z_lsst')].value
# Out:
# <ipython-input-113-80675a3f8a19>:1: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   id=photometry[('id')].value
# <ipython-input-113-80675a3f8a19>:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   redshift=photometry[('redshift')].value
# <ipython-input-113-80675a3f8a19>:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_err_g_lsst=photometry[('mag_err_g_lsst')].value
# <ipython-input-113-80675a3f8a19>:5: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_err_i_lsst=photometry[('mag_err_i_lsst')].value
# <ipython-input-113-80675a3f8a19>:6: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_err_r_lsst=photometry[('mag_err_r_lsst')].value
# <ipython-input-113-80675a3f8a19>:7: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_err_u_lsst=photometry[('mag_err_u_lsst')].value
# <ipython-input-113-80675a3f8a19>:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_err_y_lsst=photometry[('mag_err_y_lsst')].value
# <ipython-input-113-80675a3f8a19>:9: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_err_z_lsst=photometry[('mag_err_z_lsst')].value
# <ipython-input-113-80675a3f8a19>:10: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_g_lsst=photometry[('mag_g_lsst')].value
# <ipython-input-113-80675a3f8a19>:11: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_i_lsst=photometry[('mag_i_lsst')].value
# <ipython-input-113-80675a3f8a19>:12: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_r_lsst=photometry[('mag_r_lsst')].value
# <ipython-input-113-80675a3f8a19>:13: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_u_lsst=photometry[('mag_u_lsst')].value
# <ipython-input-113-80675a3f8a19>:14: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_y_lsst=photometry[('mag_y_lsst')].value
# <ipython-input-113-80675a3f8a19>:15: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   mag_z_lsst=photometry[('mag_z_lsst')].value

# %%
plt.hist(redshift,bins=100);

# %%
plt.scatter(redshift,mag_u_lsst)
plt.ylim(15,35)
# Out:
# (15.0, 35.0)

# %%
plt.scatter(redshift,mag_g_lsst)
plt.ylim(15,35)
# Out:
# (15.0, 35.0)

# %%
plt.scatter(redshift,mag_r_lsst)
plt.ylim(15,35)
# Out:
# (15.0, 35.0)

# %%
plt.scatter(redshift,mag_i_lsst)
plt.ylim(15,35)
# Out:
# (15.0, 35.0)

# %%
plt.scatter(redshift,mag_z_lsst)
plt.ylim(15,35)
# Out:
# (15.0, 35.0)

# %%
plt.scatter(redshift,mag_y_lsst)
plt.ylim(15,35)
# Out:
# (15.0, 35.0)
